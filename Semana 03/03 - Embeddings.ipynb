# %% [markdown]
# <img src="https://raw.githubusercontent.com/alan-barzilay/NLPortugues/master/imagens/logo_nlportugues.png"   width="150" align="right">
#
# # Lista 3 - Embeddings

# %% [markdown]
# ______________

# %% [markdown]
# O objetivo desta lista é fazer com que vocês treinem um modelo de análise de sentimentos utilizando um embedding. O modelo final será criado na seção "montando o modelo", mas até lá vamos passar pelas seguintes etapas:
#  - Importando os dados como um dataframe
#  - Pré Processamento
#  - Separando em teste e treino
#  - Tokenizando
#
#
# Após montar e treinar seu modelo você tambem poderá fazer uma questão extra para ganhar nota extra nessa lista, deixar de fazer esse exercicio não prejudicará sua nota.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779202143.674663 3259896 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1779202150.502341 3259896 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779202165.294596 3259896 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
tf.__version__
# Out:
# '2.21.0'

# %% [markdown]
# ### Importando os dados como um dataframe
#
# Para esta lista nós utilizaremos um recorte do dataset **B2W-Reviews01** que consiste em avaliações de mais de 130k compras online no site Americanas.com e [esta disponivel no github](https://github.com/b2wdigital/b2w-reviews01) sob a licensa CC BY-NC-SA 4.01.

# %%
# !mkdir data

# %%
# !curl https://raw.githubusercontent.com/alan-barzilay/NLPortugues/master/Semana%2003/data/b2w-10k.csv --output 'data/b2w-10k.csv'

# %%
b2wCorpus = pd.read_csv("data/b2w-10k.csv")
b2wCorpus.head()
# Out:
#        submission_date                                        reviewer_id  \
# 0  2018-01-01 00:11:28  d0fb1ca69422530334178f5c8624aa7a99da47907c44de...
# 1  2018-01-01 00:13:48  014d6dc5a10aed1ff1e6f349fb2b059a2d3de511c7538a...
# 2  2018-01-01 00:26:02  44f2c8edd93471926fff601274b8b2b5c4824e386ae4f2...
# 3  2018-01-01 00:35:54  ce741665c1764ab2d77539e18d0e4f66dde6213c9f0863...
# 4  2018-01-01 01:00:28  7d7b6b18dda804a897359276cef0ca252f9932bf4b5c8e...
#
#    product_id                                       product_name  \
# 0   132532965  Notebook Asus Vivobook Max X541NA-GO472T Intel...
# 1    22562178               Copo Acrílico Com Canudo 500ml Rocie
# 2   113022329  Panela de Pressão Elétrica Philips Walita Dail...
# 3   113851581               Betoneira Columbus - Roma Brinquedos
# 4   131788803  Smart TV LED 43" LG 43UJ6525 Ultra HD 4K com C...
#
#     product_brand      site_category_lv1       site_category_lv2  \
# 0             NaN            Informática                Notebook
# 1             NaN  Utilidades Domésticas  Copos, Taças e Canecas
# 2  philips walita        Eletroportáteis         Panela Elétrica
# 3     roma jensen             Brinquedos   Veículos de Brinquedo
# 4              lg      TV e Home Theater                      TV
#
#                        review_title  overall_rating recommend_to_a_friend  \
# 0                               Bom               4                   Yes
# 1  Preço imbatível, ótima qualidade               4                   Yes
# 2      ATENDE TODAS AS EXPECTATIVA.               4                   Yes
# 3        presente mais que desejado               4                   Yes
# 4            Sem duvidas, excelente               5                   Yes
#
#                                          review_text reviewer_birth_year  \
# 0  Estou contente com a compra entrega rápida o ú...                1958
# 1  Por apenas R$1994.20,eu consegui comprar esse ...                1996
# 2  SUPERA EM AGILIDADE E PRATICIDADE OUTRAS PANEL...                1984
# 3  MEU FILHO AMOU! PARECE DE VERDADE COM TANTOS D...                1985
# 4  A entrega foi no prazo, as americanas estão de...                1994
#
#   reviewer_gender reviewer_state Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0               F             RJ         NaN         NaN         NaN
# 1               M             SC         NaN         NaN         NaN
# 2               M             SP         NaN         NaN         NaN
# 3               F             SP         NaN         NaN         NaN
# 4               M             MG         NaN         NaN         NaN
#
#   Unnamed: 17 Unnamed: 18
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
b2wCorpus["review_text"]
# Out:
# 0       Estou contente com a compra entrega rápida o ú...
# 1       Por apenas R$1994.20,eu consegui comprar esse ...
# 2       SUPERA EM AGILIDADE E PRATICIDADE OUTRAS PANEL...
# 3       MEU FILHO AMOU! PARECE DE VERDADE COM TANTOS D...
# 4       A entrega foi no prazo, as americanas estão de...
#                               ...
# 9994    Celular muito rápido, com processador e armaze...
# 9995    achei o produto muito frágil, o material veio ...
# 9996    Uma porcaria pois ñ recebi ñ recomendo pra nin...
# 9997    Maquina excelente,super pratica. recomendo.ent...
# 9998    Agradeço pelo compromisso, obrigado. ,...........
# Name: review_text, Length: 9999, dtype: str

# %% [markdown]
# ### Pré-processamento
# Seria util nos livrarmos das colunas que não são relevantes para o nosso problema e tambem verificar se não tem nada de esquisito nas colunas que vamos utilizar.
# Por exemplo, se fossemos utilizar a coluna "reviewer_gender" nós precisariamos nos livrar desses valores esquisitos:

# %%
b2wCorpus["reviewer_gender"].value_counts()
# Out:
# reviewer_gender
# M                                                                         5033
# F                                                                         4624
#                                                                              1
# 1970                                                                         1
# Ocorrência: Z-Devolução Em Andamento Ao Cd de São Paulo 22/12/17 16:12       1
# Name: count, dtype: int64

# %% [markdown]
# ## <font color='blue'>Questão 1 </font>
#
# a) Selecione apenas as colunas relevantes: "review_text" e "recommend_to_a_friend".
#
# b) Converta a coluna "recommend_to_a_friend" de uma coluna de `str` para uma coluna de `int`:
#
# - "Yes"-> 1
# - "No" -> 0

# %%
# Seu código aqui
# a) Seleciona apenas as colunas relevantes e remove linhas nulas
data = b2wCorpus.dropna(subset=["review_text", "recommend_to_a_friend"])[["review_text", "recommend_to_a_friend"]].copy()

# b) Filtra somente Yes/No e converte para int sem SettingWithCopyWarning
mask = data["recommend_to_a_friend"].isin(["Yes", "No"])
data = data.loc[mask].copy()
data["recommend_to_a_friend"] = data["recommend_to_a_friend"].map({"Yes": 1, "No": 0}).astype(int)

# %% [markdown]
# ### Separando em teste e treino
# ## <font color='blue'>Questão 2 </font>
#
# Agora com o dataset já pré-processado, separe o em 2 partes, um conjunto de teste e um conjunto de treino. Novamente você pode utilizar a função [train_test_split()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) do Scikit-Learn como na lista passada.

# %%
from sklearn.model_selection import train_test_split

# %%
# Seu código aqui

# --- PREPARACAO DOS DADOS ----
x = data[["review_text"]].values
y = data["recommend_to_a_friend"].values
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Tokenizando
#
# Para alimentarmos os reviews a camada de embedding nós precisamos quebrar cada review em uma serie de tokens. Existem diversas maneiras de se realizar isso e poderiamos até mesmo usar outras bibliotecas como o spaCy.
#
# Por exemplo, o objeto [`Tokenizer`](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/text/Tokenizer) oferece um método `tokenize` para quebrar as palavras em tokens individuais ao mesmo tempo que filtra caracteres indesejados (por default os caracteres filtrados são: !"#$\%&()*+,-./:;<=>?@[\\]^_\`{|}~\t\n).
#
#
# Para essa lista utilizaremos a camada [`TextVectorization`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/TextVectorization) para automaticamente passar os reviews para caixa-baixa, extrair caracteres especiais e tokenizar as palavras de maneira a serem passadas para a camada de embedding. Ao tornarmos a etapa de tokenização uma camada de rede neural nós podemos incluir esse processamento dos reviews no proprio modelo.

# %% [markdown]
# ## <font color='blue'>Questão 3 </font>
# Utilizando a camada `TextVectorization` tokenize os inputs.
# Declare a camada e então chame a função `adapt()` para adequar o seu vocabulário aos reviews.
#
# Não se esqueça de se certificar que todas os reviews tenham o mesmo comprimento, seja por meio do uso de padding, truncamento ou uma mistura dos dois. Plotamos um histograma do comprimento dos reviews para lhe auxiliar nessa decisão.

# %%
plt.hist([len(linha.split()) for linha in b2wCorpus["review_text"]])
plt.show()

# %%
from tensorflow.keras.layers import TextVectorization
from tensorflow.keras import layers

# %%
# Seu código aqui

# --- VETORIZACAO ---
maxlen = 61  # comprimento fixo das sequências (ex.: percentil 95 dos comprimentos)
vocab_size = 20000  # número máximo de tokens no vocabulário (inclui OOV)

vectorizer = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",  # converte texto em inteiros (ids de tokens)
    output_sequence_length=maxlen,  # garante sequências de comprimento fixo (pad/trunc)
)

vectorizer.adapt(x_train.flatten())

x_train_vec = vectorizer(x_train)
x_val_vec = vectorizer(x_val)

# %% [markdown]
# ### Montando o modelo
#
# Agora vamos juntar a camada do tokenizador a nossa camada [Embedding](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding) e definir o resto de nosso modelo.
#
# ##  <font color='blue'>Questão 4 </font>
#
# Defina seu modelo.
#
# Como analise de sentimentos pode ser visto como um problema de classificação, é interessante também registrar algumas métricas como acurácia `metrics=["acc"]` .
#
# Seu modelo deve começar com a seguinte estrutura:
#  - Camada de Input
#  - Camada de Tokenização
#  - Camada de Embedding
#
# Já definimos as camadas seguintes da rede por você.
#
# Atenção a dimensão do input da camada de embedding, lembre se que < OOV > e < PAD > possuem seus próprios tokens.

# %%
model = tf.keras.Sequential([    

    ############ Seu código aqui##################
    # --- EMBEDDING ---
    tf.keras.layers.Embedding(
        input_dim=vocab_size,
        output_dim=128,
    ),

    ##############################################
    # Conv1D + global max pooling
    layers.Conv1D(128, 7, padding='valid', activation='relu', strides=3),
    layers.Conv1D(128, 7, padding='valid', activation='relu', strides=3),
    layers.GlobalMaxPooling1D(),

    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid'),
])

# %% [markdown]
# ### Treinando e avaliando seu modelo
#
# ##  <font color='blue'>Questão 5 </font>
#
# Com seu modelo definido, treine e avalie sua performance no conjunto de testes.

# %%
# Seu código aqui

# --- COMPILACAO E TREINO ---
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=['accuracy'])
model.fit(x_train_vec, y_train, epochs=51, validation_data=(x_val_vec, y_val))
model.evaluate(x=x_val_vec, y=y_val)
# Out:
# Epoch 1/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.8321 - loss: 0.3908 - val_accuracy: 0.8915 - val_loss: 0.2620
# Epoch 2/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9390 - loss: 0.1801 - val_accuracy: 0.8955 - val_loss: 0.2546
# Epoch 3/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.9792 - loss: 0.0751 - val_accuracy: 0.8755 - val_loss: 0.3965
# Epoch 4/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9940 - loss: 0.0245 - val_accuracy: 0.8750 - val_loss: 0.5019
# Epoch 5/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9962 - loss: 0.0135 - val_accuracy: 0.8690 - val_loss: 0.6635
# Epoch 6/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9982 - loss: 0.0053 - val_accuracy: 0.8810 - val_loss: 0.8176
# Epoch 7/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.8760 - val_loss: 0.7232
# Epoch 8/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9970 - loss: 0.0094 - val_accuracy: 0.8685 - val_loss: 0.8150
# Epoch 9/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9947 - loss: 0.0128 - val_accuracy: 0.8700 - val_loss: 0.7334
# Epoch 10/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9982 - loss: 0.0056 - val_accuracy: 0.8650 - val_loss: 1.1408
# Epoch 11/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9970 - loss: 0.0115 - val_accuracy: 0.8730 - val_loss: 0.8292
# Epoch 12/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - accuracy: 0.9982 - loss: 0.0047 - val_accuracy: 0.8650 - val_loss: 1.1834
# Epoch 13/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9966 - loss: 0.0119 - val_accuracy: 0.8565 - val_loss: 1.1950
# Epoch 14/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9972 - loss: 0.0078 - val_accuracy: 0.8685 - val_loss: 1.0748
# Epoch 15/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9987 - loss: 0.0039 - val_accuracy: 0.8695 - val_loss: 1.1317
# Epoch 16/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.8680 - val_loss: 1.2467
# Epoch 17/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.8640 - val_loss: 1.4112
# Epoch 18/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9994 - loss: 0.0012 - val_accuracy: 0.8705 - val_loss: 1.4860
# Epoch 19/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9994 - loss: 0.0012 - val_accuracy: 0.8705 - val_loss: 1.6161
# Epoch 20/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.8715 - val_loss: 1.6100
# Epoch 21/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9994 - loss: 0.0012 - val_accuracy: 0.8710 - val_loss: 1.7241
# Epoch 22/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.8720 - val_loss: 1.8210
# Epoch 23/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9994 - loss: 0.0014 - val_accuracy: 0.8725 - val_loss: 1.8394
# Epoch 24/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9995 - loss: 0.0010 - val_accuracy: 0.8690 - val_loss: 1.8644
# Epoch 25/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9995 - loss: 0.0010 - val_accuracy: 0.8700 - val_loss: 1.8947
# Epoch 26/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.8705 - val_loss: 1.9763
# Epoch 27/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9994 - loss: 0.0010 - val_accuracy: 0.8735 - val_loss: 2.0629
# Epoch 28/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.8725 - val_loss: 2.0072
# Epoch 29/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9994 - loss: 0.0013 - val_accuracy: 0.8710 - val_loss: 1.9508
# Epoch 30/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9994 - loss: 0.0012 - val_accuracy: 0.8715 - val_loss: 1.9162
# Epoch 31/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.8705 - val_loss: 1.9468
# Epoch 32/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9994 - loss: 0.0016 - val_accuracy: 0.8705 - val_loss: 1.8801
# Epoch 33/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9994 - loss: 0.0015 - val_accuracy: 0.8745 - val_loss: 1.9061
# Epoch 34/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9891 - loss: 0.0424 - val_accuracy: 0.8495 - val_loss: 0.6742
# Epoch 35/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.9940 - loss: 0.0193 - val_accuracy: 0.8635 - val_loss: 0.9894
# Epoch 36/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9990 - loss: 0.0040 - val_accuracy: 0.8650 - val_loss: 0.9810
# Epoch 37/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.8635 - val_loss: 1.2459
# Epoch 38/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.8640 - val_loss: 1.3985
# Epoch 39/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.8650 - val_loss: 1.5150
# Epoch 40/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.8625 - val_loss: 1.6393
# Epoch 41/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.8625 - val_loss: 1.7291
# Epoch 42/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9995 - loss: 0.0010 - val_accuracy: 0.8655 - val_loss: 1.8308
# Epoch 43/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9994 - loss: 0.0010 - val_accuracy: 0.8655 - val_loss: 1.9381
# Epoch 44/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9995 - loss: 0.0011 - val_accuracy: 0.8670 - val_loss: 2.0644
# Epoch 45/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.8625 - val_loss: 2.0165
# Epoch 46/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9994 - loss: 0.0011 - val_accuracy: 0.8640 - val_loss: 2.0572
# Epoch 47/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.8640 - val_loss: 2.1035
# Epoch 48/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9995 - loss: 9.7798e-04 - val_accuracy: 0.8670 - val_loss: 2.1488
# Epoch 49/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9994 - loss: 9.4953e-04 - val_accuracy: 0.8655 - val_loss: 2.1334
# Epoch 50/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9995 - loss: 0.0011 - val_accuracy: 0.8635 - val_loss: 2.1498
# Epoch 51/51
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9995 - loss: 0.0011 - val_accuracy: 0.8670 - val_loss: 2.2514
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8670 - loss: 2.2514
# [2.251350164413452, 0.8669999837875366]

# %% [markdown]
# ##  <font color='green'>Questão Extra </font>
#
# ### Vizualizando o embedding
# Agora que temos um embedding treinado em nossa tarefa de analise de sentimentos, podemos tentar vizualisar este embedding. O [embedding projector](https://projector.tensorflow.org/) nos permite visualiza-los de maneira mais intuitiva.
#
# Para carregar seu próprio embedding você precisará fornecer 2 arquivos, um com os embeddings propriamente ditos e outro com os métadados (no nosso caso, um string que representa a palavra).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Esse [guia](https://www.tensorflow.org/tensorboard/tensorboard_projector_plugin) pode ser util para entender melhor como extrair essas informações.

# %%
# Seu código aqui
# Out:
# Arquivos do Projector gravados em logs/projector

# %% [markdown]
# Procure por palavras com conotações tradicionalmente positivas e negativas, elas estão proximas ou distantes?
# Usando a visualização PCA, você consegue notar alguma característica interessante sobre como as palavras estão distribuidas nesse espaço?

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**
