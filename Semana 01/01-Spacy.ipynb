# %% [markdown]
# <img src="https://raw.githubusercontent.com/alan-barzilay/NLPortugues/master/imagens/logo_nlportugues.png"   width="150" align="right">
#
#
#
# # Lista 1 - spaCy

# %% [markdown]
# ---

# %% [markdown]
# O [spaCy]("https://spacy.io") é uma bilbioteca Python de código fonte [aberto]("https://github.com/explosion/spaCy") para Processamento de
# Linguagem Natural, constantemente atualizada e mantida. Essa biblioteca é capaz de
# processar diversas línguas, inclusive o português.
#
# ### Instalação

# %%
# %pip install spacy -U
# Out:
# Requirement already satisfied: spacy in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (0.25.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.4.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: anyio in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: wrapt in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: mdurl~=0.1 in /home/guilherme/Workspace/curso/NLPortugues/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Após instalar o pacote spaCy devemos baixar as ferramentas específicas para o português  com o seguinte comando:

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# Collecting pt-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.8.0/pt_core_news_sm-3.8.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 3.0 MB/s eta 0:00:0000:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %% [markdown]
# Uma vez que temos o pacote instalado e os módulos para português baixado,  podemos começar a utilizar  o spaCy, importando o pacote e carregando o módulo para português.
#
# **Nota:** Caso seus resultados sejam diferentes dos descritos neste texto isso provavelmente significa que você está utilizando uma versão diferente do spaCy, como essa ferramenta é atualizada com frequência não é incomum encontrar discrepâncias nos resultados.

# %%
import spacy
import pt_core_news_sm
spacyPT = pt_core_news_sm.load()

# %%
spacy.__version__
# Out:
# '3.8.14'

# %% [markdown]
# É importante notar que o spaCy assume que os caracteres estão codificados no formato utf-8.  O primeiro passo portanto é gerar uma entrada nesse formato e submetê-la ao módulo carregado.

# %%
entrada = spacyPT("Mais vale um asno que me carregue que um cavalo que me derrube.")
entrada
# Out:
# Mais vale um asno que me carregue que um cavalo que me derrube.

# %% [markdown]
# ### Tokenização (itemização)
#
# A entrada que acabamos de gerar é uma sequência iterável de tokens (itens,
# ou instâncias de palavras). Se quisermos verificar qual o texto contido nessa
# sequência iterável,  usamos:

# %%
entrada.text
# Out:
# 'Mais vale um asno que me carregue que um cavalo que me derrube.'

# %% [markdown]
# Se quisermos dividir a entrada em token,  podemos utilizar o método __split__:

# %%
entrada.text.split()
# Out:
# ['Mais',
#  'vale',
#  'um',
#  'asno',
#  'que',
#  'me',
#  'carregue',
#  'que',
#  'um',
#  'cavalo',
#  'que',
#  'me',
#  'derrube.']

# %% [markdown]
# Note que o ponto  final foi absorvido pela palavra;  o mesmo teria acontecido com
# outros sinais de pontuação a utilizar  o método __split__. Para separar a pontuação
# das palavras utilizamos a  tokenização implícita realizada pelo comando __in__:

# %%
[token for token in entrada]
# Out:
# [Mais, vale, um, asno, que, me, carregue, que, um, cavalo, que, me, derrube, .]

# %% [markdown]
# Note que os streams não estão entre aspas,  pois na realidade esta lista contém uma sequência de objetos da classe __Token__.
#
# Se o objetivo é obter uma lista de Strings,  podemos proceder da seguinte maneira.

# %%
[token.text for token in entrada]
# Out:
# ['Mais',
#  'vale',
#  'um',
#  'asno',
#  'que',
#  'me',
#  'carregue',
#  'que',
#  'um',
#  'cavalo',
#  'que',
#  'me',
#  'derrube',
#  '.']

# %% [markdown]
# E para eliminar totalmente a pontuação da lista,  é só restringirr  a sua criação usando __is_punct__.

# %%
[token.text for token in entrada if not token.is_punct]
# Out:
# ['Mais',
#  'vale',
#  'um',
#  'asno',
#  'que',
#  'me',
#  'carregue',
#  'que',
#  'um',
#  'cavalo',
#  'que',
#  'me',
#  'derrube']

# %% [markdown]
# O spaCy já vem treinado para realizar etiquetagem morfossintática (PoS tagging),  o que pode ser mostrado da seguinte maneira.

# %%
[(token.text, token.pos_) for token in entrada]
# Out:
# [('Mais', 'ADV'),
#  ('vale', 'VERB'),
#  ('um', 'DET'),
#  ('asno', 'NOUN'),
#  ('que', 'PRON'),
#  ('me', 'PRON'),
#  ('carregue', 'VERB'),
#  ('que', 'SCONJ'),
#  ('um', 'DET'),
#  ('cavalo', 'NOUN'),
#  ('que', 'PRON'),
#  ('me', 'PRON'),
#  ('derrube', 'PROPN'),
#  ('.', 'PUNCT')]

# %% [markdown]
# A assistência do etiquetador nos permite fazer buscas bastante sofisticadas. Por exemplo podemos buscar os lemas de todos os verbos encontrados  na sentença.

# %%
[token.lemma_ for token in entrada if token.pos_ == 'VERB']
# Out:
# ['valer', 'carregar']

# %% [markdown]
# Os lemas de verbos conjugados nos fornecem  a sua forma infinitiva.

# %% [markdown]
# ### Reconhecimento de entidades nomeadas
#
# A biblioteca já vem treinada com um  mecanismo que permite o reconhecimento de
# entidades nomeadas.

# %%
texto2 = spacyPT("A CBF fez um pedido de análise ao Comitê de Apelações da FIFA a fim de diminuir a pena do atacante Neymar, suspenso da Copa América pela Conmebol.")
print(texto2.ents)
[(entidade,entidade.label_) for entidade in texto2.ents]
# Out:
# (CBF, Comitê de Apelações da FIFA, Neymar, Copa América, Conmebol)
# [(CBF, 'ORG'),
#  (Comitê de Apelações da FIFA, 'ORG'),
#  (Neymar, 'PER'),
#  (Copa América, 'MISC'),
#  (Conmebol, 'ORG')]

# %% [markdown]
# ___________________________
# # <font color='blue'>  Questão 1 </font>
#
# Utilizando o spacy, extraia o nome dos personagens presentes no terceiro capitulo da obra "Mémorias postumas de Brás Cubas" de Machado de Assis

# %%
cap_3_bras_cubas = "Mas, já que falei nos meus dois tios, deixem-me fazer aqui um curto esboço genealógico.        O fundador de minha família foi um certo Damião Cubas, que floresceu na primeira metade do século XVIII. Era tanoeiro de ofício, natural do Rio de Janeiro, onde teria morrido na penúria e na obscuridade, se somente exercesse a tanoaria. Mas não; fez-se lavrador, plantou, colheu, permutou o seu produto por boas e honradas patacas, até que morreu, deixando grosso cabedal a um filho, o licenciado Luís Cubas. Neste rapaz é que verdadeiramente começa a série de meus avós -- dos avós que a minha família sempre confessou -  porque o Damião Cubas era afinal de contas um tanoeiro, e talvez mau tanoeiro, ao passo que o Luís Cubas estudou em Coimbra, primou no Estado, e foi um dos amigos particulares do vice-rei conde da Cunha.        Como este apelido de Cubas lhe cheirasse excessivamente a tanoaria, alegava meu pai, bisneto do Damião, que o dito apelido fora dado a um cav
# [(Damião Cubas, 'PER'),
#  (Luís Cubas, 'PER'),
#  (Damião Cubas, 'PER'),
#  (Luís Cubas, 'PER'),
#  (conde da Cunha, 'PER'),
#  (Damião, 'PER'),
#  (Brás Cubas, 'PER'),
#  (Brás, 'PER')]

# %% [markdown]
# Quais destas repostas estão corretas?  Quais personagens estão faltando?

# %% [markdown]
# **<font color='red'> Sua resposta aqui </font>**
#
# Estão faltando Venância e Contrim.

# %% [markdown]
# # <font color='blue'>  Questão 2 </font>
#
# Extraia todos os pronomes deste capitulo.
#
# _____________
# **<font color='red'> Sua resposta aqui </font>**

# %%
#Seu código aqui
[(token.text, token.pos_) for token in cap_3_bras_cubas if token.pos_ == 'PRON']
# Out:
# [('que', 'PRON'),
#  ('onde', 'PRON'),
#  ('que', 'PRON'),
#  ('que', 'PRON'),
#  ('lhe', 'PRON'),
#  ('que', 'PRON'),
#  ('que', 'PRON'),
#  ('poucos', 'PRON'),
#  ('quem', 'PRON'),
#  ('ele', 'PRON'),
#  ('que', 'PRON'),
#  ('onde', 'PRON'),
#  ('me', 'PRON'),
#  ('ele', 'PRON'),
#  ('que', 'PRON'),
#  ('que', 'PRON')]

# %% [markdown]
# # <font color='blue'>  Questão 3 </font>
# Utilize os visualizadores para explorar o mapa de dependencias de uma frase a sua escolha deste capitulo.
# https://spacy.io/usage/visualizers
#
# Você pode acessar diretamente uma frase especifica ao utilizar o gerador "sents", por exemplo:
#
# ```python
# frases = [frase for frase in texto.sents]
# frases[2]
#
#
# Era tanoeiro de ofício, natural do Rio de Janeiro LOC , onde teria morrido na penúria e na obscuridade, se somente exercesse a tanoaria.
# ```
#
#
# _______________
#
#
# **<font color='red'> Sua resposta aqui </font>**

# %%
from spacy import displacy

# %%
#Seu código aqui
frases = [frase for frase in cap_3_bras_cubas.sents]
frases[1]

displacy.render(frases[1], style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="e160004807334390a1ff1cc2638f39c7-0" class="displacy" width="3200" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">fundador</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">minha</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">família</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">foi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">um</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">certo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Damião</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Cubas,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">floresceu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">na</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">primeira</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">metade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">século</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">XVIII.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e160004807334390a1ff1cc2638f39c7-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e160004807334390a1ff1cc2638f39c7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e160004807334390a1ff1cc2638f39c7-0-1" stroke-width="2px" d="M245,352.0 C245,2.0 1275.0,2.0 1275.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e160004807334390a1ff1cc2638f39c7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e160004807334390a1ff1cc2638f39c7-0-2" stroke-width="2px" d="M420,352.0 C420,177.0 740.0,177.0 740.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e160004807334390a1ff1cc2638f39c7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e160004807334390a1ff1cc2638f39c7-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e160004807334390a1ff1cc2638f39c7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e160004807334390a1ff1cc2638f39c7-0-4" stroke-width="2px" d="M245,352.0 C245,89.5 745.0,89.5 745.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e160004807334390a1ff1cc2638f39c7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,354.0 L753.0,342.0 737.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e160004807334390a1ff1cc2638f39c7-0-5" stroke-width="2px" d="M945,352.0 C945,177.0 1265.0,177.0 1265.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#ar

# %% [markdown]
# # Fontes
# Tanto o capitulo utilizado nesta aula quanto a obra completa fazem parte do dominio publico e podem ser encontrados em http://www.dominiopublico.gov.br/download/texto/bv000215.pdf
